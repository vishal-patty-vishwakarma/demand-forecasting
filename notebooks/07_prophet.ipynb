# %% [markdown]
# ## Notebook 07: Prophet — Skipped (Windows Compatibility)
#
# ### Why Prophet was skipped
# Prophet requires CmdStan which needs C++ build tools on Windows.
# Installation failed with: "make build" error — mingw32-make not found.
# This is a known Windows compatibility issue with Prophet 1.1.5.
#
# ### What Prophet would have shown
# - External regressors (oil price, holidays) improve accuracy
# - Interpretable component decomposition (trend, weekly, yearly)
# - Holiday effects quantified separately
#
# ### Why this doesn't affect our project
# LightGBM already includes all Prophet's external regressors:
# - oil_price and oil_price_change_pct (economic driver)
# - is_holiday (11.4% uplift confirmed in EDA)
# - discount_depth (promotion flag)
#
# LightGBM feature importance will show us which external
# regressors matter most — same insight, different method.
#
# ### Decision
# Proceed directly to LightGBM global model.
# Prophet can be added later with: conda install -c conda-forge prophet

# %%
# Prophet skipped — documenting decision
decision = {
    "notebook": "07_prophet",
    "status": "skipped",
    "reason": "Windows CmdStan build failure — mingw32-make not found",
    "impact": "None — LightGBM includes same external regressors",
    "future_fix": "conda install -c conda-forge prophet"
}

for k, v in decision.items():
    print(f"{k:15}: {v}")
# Out:
# notebook       : 07_prophet
# status         : skipped
# reason         : Windows CmdStan build failure — mingw32-make not found
# impact         : None — LightGBM includes same external regressors
# future_fix     : conda install -c conda-forge prophet
